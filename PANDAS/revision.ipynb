# %%
import pandas as pd
runs = [1,45,22,78,55]
pd.Series(runs)
# Out:
# 0     1
# 1    45
# 2    22
# 3    78
# 4    55
# dtype: int64

# %%
marks = [34,22,55,100]
subjects = ['maths', 'english', 'hindi', 'science']

pd.Series(marks, index = subjects, name = "Shubham's marks")
# Out:
# maths       34
# english     22
# hindi       55
# science    100
# Name: Shubham's marks, dtype: int64

# %%
marks = {
    'maths' : 89,
    'english' : 100,
    'hindi' : 78,
    'science' : 100
}

pd.Series(marks, name='Shubham Marks')
# Out:
# maths       89
# english    100
# hindi       78
# science    100
# Name: Shubham Marks, dtype: int64

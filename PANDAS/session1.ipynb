# %% [markdown]
# # PANDAS

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## series from lists

# %%
country = ['India', 'Nepal', 'USA', "China"]
pd.Series(country)
# Out:
# 0    India
# 1    Nepal
# 2      USA
# 3    China
# dtype: object

# %%
#integer series:

runs = [13,54,100,76,0,1]
pd.Series(runs)
# Out:
# 0     13
# 1     54
# 2    100
# 3     76
# 4      0
# 5      1
# dtype: int64

# %%
#custom index:

# %% [markdown]
# # Recusrsion

# %%
#eg: if we dont have any mulitplication operator(*)

#using loops:

def mult(a,b):
    result = 0

    for i in range(b):
        result += a

    print(result)

mult(3,5)
# Out:
# 15

# %%
#using recusrion:

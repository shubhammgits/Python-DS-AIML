# %% [markdown]
# # Tuples

# %%
t1 = ()
type(t1)
# Out:
# tuple

# %%
t1 = (2,)
t2 = ('hello',)
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
t3 = (1,2,3,4) #hetro
t4 = (1,True, [1,2,3], 'hello')

print(t3)
print(t4)
# Out:
# (1, 2, 3, 4)
# (1, True, [1, 2, 3], 'hello')

# %%
t5 = (1,2,3,('hello', True)) #2d

print(t5)
# Out:
# (1, 2, 3, ('hello', True))

# %%
t6 = tuple('hello')
print(t6)
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
#Accessing items:

t3 = (1,2,3,4)

print(t3[0])
print(t3[-1])

print(t3[1:3])
print(t3[::-1])
# Out:
# 1
# 4
# (2, 3)
# (4, 3, 2, 1)

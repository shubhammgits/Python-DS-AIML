# %%
for i in range(5,0,-1):
    for j in range(i,0,-1):
        print(j,end=' ')
    print()
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %%
for i in range(1,7):
    for j in range(1,i):
        print('*', end=' ')
    print()

for i in range(4,0,-1):
    for j in range(i,0,-1):
        print('*', end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(4,0):
    for j in range(i,4):
        print(' '*)

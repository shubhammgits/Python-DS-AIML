# %% [markdown]
# ### revision

# %%
a = int(input('Enter the first number : '))
b = int(input('Enter the second number : '))

print(f'Sum of {a} and {b} is : ',a+b)
# Out:
# Sum of 4 and 5 is :  9

# %%
fruits = ['apple', 'mango']

fruits.append('banana')
print(fruits)
# Out:
# ['apple', 'mango', 'banana']

# %%
coord = (10,20,30)
coord[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 coord = (10,20,30)
# ----> 2 coord[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
dict1 = {'name' : 'Shubham', 'age' : 20, 'branch' : 'cse'}
print(dict1)

dict1['year'] = 3

dict1
# Out:
# {'name': 'Shubham', 'age': 20, 'branch': 'cse'}
# {'name': 'Shubham', 'age': 20, 'branch': 'cse', 'year': 3}

# %%
t = (1,2,True)
print(t)

t[2] = False
# Out:
# (1, 2, True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 t = (1,2,True)
#       2 print(t)
# ----> 4 t[2] = False
#
# TypeError: 'tuple' object does not support item assignment

# %%
s = 'Hello'
print(id(s))

s = s + ' World'
print(id(s))
# Out:
# 2735651937456
# 2735628539184

# %%
def add(a,b):
    return a+b

add(3,4)
# Out:
# 7

# %%
square = lambda x : x**2
square(8)
# Out:
# 64

# %%
add = lambda x,y : x+y
add(3,4)
# Out:
# 7

# %%
def greet(name = 'User'):
    print(f'Hello {name}')

greet('Shubham')
# Out:
# Hello Shubham

# %%
def add(*args):
    sum = 0
    for num in args:
        sum+=num
    return sum

add(1,2,3)
# Out:
# 6

# %%
def student_info(**kwargs):
    for key,value in kwargs.items():
        print(key, ':', value)

student_info(name='Shubham', age=20, city='Delhi')
# Out:
# name : Shubham
# age : 20
# city : Delhi

# %%
names = ['Rahul', 'Aisha', "Zara", 'Mike']

names.sort(key = lambda x : x.lower())
print(names)
# Out:
# ['Aisha', 'Mike', 'Rahul', 'Zara']

# %%
l = 'a,b,c'.split(',')
print(l)
# Out:
# ['a', 'b', 'c']

# %%
name = 'Shubham Kumar Jha'.split(' ')
print(name)
# Out:
# ['Shubham', 'Kumar', 'Jha']

# %%
'  '.join(['Shubham', 'Kumar', 'Jha'])
# Out:
# 'Shubham  Kumar  Jha'

# %%
s1 = 'bat'
print(s1)
print(id(s1))
s2 = s1.replace('b', 'c')
print(s2)
print(id(s2))
# Out:
# bat
# 2735600769840
# cat
# 2735651007024

# %%
l =[1,2,3,3,3,2]

l.find(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 l =[1,2,3,3,3,2]
# ----> 3 l.find(2)
#
# AttributeError: 'list' object has no attribute 'find'

# %%
s = 'Shubham'
s.find('h')
# Out:
# 1

# %%
l = [1,2,3,3,3,3,2]
l.count(3)
# Out:
# 4

# %%
s='12233112'
s.count('2')
# Out:
# 3

# %%
'abc'.isalnum()
# Out:
# True

# %%
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
str(a)
# Out:
# '4'

# %%
str(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 str(n)
#
# NameError: name 'n' is not defined

# %%
try:
    a=int(input('Enter the first number :'))
    b = int(input('Enter the second number :'))
    result = a/b
    print('Result : ',result)

except ZeroDivisionError:
    print('Cant divide by zero!')

except ValueError:
    print('Please enter  valis int value!')

except Exception as e:
    print(f'Unexpected error : {e}')

else:
    print('Division Succesful!')

finally:
    print('Program execution coplete!')
# Out:
# Please enter  valis int value!
# Program execution coplete!

# %%
import os

# %%
for root,dirs,files in os.walk('.'):
    print(f'Directories : {root}')
    for d in dirs:
        print(f'Sub-dir : {d}')
    for f in files:
        print(f'Files : {f}')
# Out:
# Directories : .
# Sub-dir : Tasks
# Files : big.txt
# Files : complex.txt
# Files : demo.json
# Files : int.txt
# Files : ITERATOR.ipynb
# Files : me.jpg
# Files : me_copy.jpg
# Files : person.pkl
# Files : questions.ipynb
# Files : RECURSION.ipynb
# Files : revision.ipynb
# Files : sample.txt
# Files : sample1.txt
# Files : Session1.ipynb
# Files : Session10.ipynb
# Files : Session11.ipynb
# Files : Session12.ipynb
# Files : Session2.ipynb
# Files : Session3.ipynb
# Files : Session4.ipynb
# Files : session5.ipynb
# Files : Session6.ipynb
# Files : Session7.ipynb
# Files : Session8.ipynb
# Files : Session9.ipynb
# Directories : .\Tasks
# Files : task1.ipynb
# Files : task2.ipynb
# Files : task3.ipynb

# %%
def merge_files_uppercase(file1, file2, )
# Out:
#   Cell In[56], line 1
#     def merge_files_uppercase(file1, file2, )
#                                              ^
# SyntaxError: expected ':'

# %%
import webbrowser

# %%
webbrowser.open('https://www.google.com')
# Out:
# True

# %% [markdown]
# # OOPS

# %%
#Class

L=[1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'
